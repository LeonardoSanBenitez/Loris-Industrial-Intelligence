# %% [markdown]
# # Conceptualization
# * This component takes two CSV files as input
# * Those CSV can be generated from a excel file, a SQL or non-SQL database, a power BI enviroment, and so forth

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10000000)

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

FLAG_EXPORT = False

# %%
raw1 = pd.read_csv ("../../datasets/brasilia_case_climatic.csv", header=0)
raw1.head()
# Out:
#                 timestamp  temp_celsius  pression  precipitation  \
# 0  2018-01-31 00:00:00-02            21    1011.7            0.0
# 1  2018-01-31 01:00:00-02            21    1011.5            0.0
# 2  2018-01-31 02:00:00-02            20    1011.0            0.0
# 3  2018-01-31 03:00:00-02            20    1010.2            0.0
# 4  2018-01-31 04:00:00-02            20    1009.9            0.0
#
#    windspeed_mps
# 0            1.2
# 1            1.5
# 2            1.8
# 3            1.7
# 4            1.8

# %%
raw1.describe()
# Out:
#        temp_celsius      pression  precipitation  windspeed_mps
# count  16365.000000  16365.000000   16365.000000   16365.000000
# mean      21.709502   1015.286227       0.093981       2.228555
# std        3.870892      3.177252       0.504643       1.040920
# min       10.000000   1005.100000       0.000000       0.000000
# 25%       19.000000   1013.100000       0.000000       1.500000
# 50%       21.000000   1015.100000       0.000000       2.000000
# 75%       24.000000   1017.400000       0.000000       2.800000
# max       34.000000   1026.300000      18.000000       7.900000

# %%
raw1.plot.kde(subplots=True, sharex=False, figsize=(10,4), layout=(2,2))
if FLAG_EXPORT: plt.savefig('graph_kde1.svg', format='svg')

# %%
raw1['timestamp'] = pd.to_datetime (raw1['timestamp'], utc=True)
raw1 = raw1.set_index(raw1.timestamp)
raw1 = raw1.drop ('timestamp', axis=1)

raw1 = raw1.set_index(raw1.index.tz_convert(None) + pd.offsets.Hour(-2)) # correct to brazilian timezone

# %%
filtered1 = raw1.resample('10min').interpolate(method='akima', limit_area='inside')

# %%
Axis = filtered1.plot(subplots=True, sharex=True, figsize=(12,8))

# %% [markdown]
# # Electrical database exploration
# * Convert index to timestamp
# * Resample by hour
# * Calculates load factor

# %%
raw2 = pd.read_csv ("../../datasets/brasilia_case_electric.csv", header=0)
raw2.describe()
# Out:
#                 p3           s3       cosphi      voltage   month  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1441.0
# mean    253.278387   257.380985     0.969666   222.823823     2.0
# std     174.198142   173.753180     0.024352     1.815015     0.0
# min      64.073333    69.127717     0.922886   219.477554     2.0
# 25%      80.156691    85.212165     0.941738   221.331966     2.0
# 50%     173.646250   176.529385     0.982852   222.489455     2.0
# 75%     440.549926   444.681563     0.991509   224.147700     2.0
# max     560.084167   564.114860     0.994201   227.402126     2.0
#
#               hour    dayofweek
# count  1441.000000  1441.000000
# mean     11.492019     4.000694
# std       6.928813     0.026343
# min       0.000000     4.000000
# 25%       5.000000     4.000000
# 50%      11.000000     4.000000
# 75%      17.000000     4.000000
# max      23.000000     5.000000

# %%
raw2[['p3', 's3', 'cosphi', 'voltage']].plot.kde(subplots=True, sharex=False, figsize=(10,4), layout=(2,2))
if FLAG_EXPORT: plt.savefig('graph_kde2.svg', format='svg')

# %%
raw2['timestamp'] = pd.to_datetime (raw2['timestamp']) # already was in brazilian timezone
raw2 = raw2.set_index(raw2.timestamp)
raw2 = raw2.drop ('timestamp', axis=1)

# %%
# Resample
resampled2 = raw2.resample('10min').agg({
    'voltage': ['mean', 'count'],
    'cosphi': ['mean', 'std'],
    'month': ['mean'],
    'hour': ['mean'],
    'dayofweek': ['mean'],
    'p3': ['mean', 'max', 'std']
})

resampled2.columns = resampled2.columns.map('_'.join)
resampled2 = resampled2.dropna()
#resampled2.plot(subplots=True)

# %%
filtered2 = resampled2[(resampled2['voltage_count'] == 10)]
filtered2 = filtered2.drop('voltage_count', axis=1)

# %%
filtered2['load_factor'] = filtered2['p3_mean']/filtered2['p3_max']

# %%
filtered2 = filtered2.drop('p3_max', axis=1)

# %%
filtered2.head()
# Out:
#                      voltage_mean  cosphi_mean  cosphi_std  month_mean  \
# timestamp
# 2018-02-01 00:00:00    222.422553     0.931323    0.003132           2
# 2018-02-01 00:10:00    221.822300     0.938584    0.003327           2
# 2018-02-01 00:20:00    222.539326     0.933304    0.004393           2
# 2018-02-01 00:30:00    222.744070     0.934903    0.005175           2
# 2018-02-01 00:40:00    222.832179     0.936927    0.003765           2
#
#                      hour_mean  dayofweek_mean    p3_mean    p3_std  \
# timestamp
# 2018-02-01 00:00:00          0               4  76.384250  2.901398
# 2018-02-01 00:10:00          0               4  79.409299  4.679058
# 2018-02-01 00:20:00          0               4  74.200246  3.366907
# 2018-02-01 00:30:00          0               4  76.059915  2.742411
# 2018-02-01 00:40:00          0               4  77.216275  2.191767
#
#                      load_factor
# timestamp
# 2018-02-01 00:00:00     0.936588
# 2018-02-01 00:10:00     0.916590
# 2018-02-01 00:20:00     0.950006
# 2018-02-01 00:30:00     0.949632
# 2018-02-01 00:40:00     0.963748

# %% [markdown]
# # Data integration
# * if precipitation<0: precipitation=0

# %%
merged = pd.merge (filtered1, filtered2,how='inner', left_index=True, right_index=True).astype('float')

# %%
merged.loc[merged['precipitation']<0, 'precipitation']=0

# %%
merged.describe()
# Out:
#        temp_celsius     pression  precipitation  windspeed_mps  voltage_mean  \
# count    143.000000   143.000000     143.000000     143.000000    143.000000
# mean      21.297203  1010.524350       0.153000       2.957437    222.829559
# std        1.609649     1.644249       0.237205       1.249292      1.796251
# min       19.000000  1006.900000       0.000000       1.071111    220.005119
# 25%       20.000000  1009.711944       0.000000       1.841630    221.343998
# 50%       20.962963  1010.552517       0.074074       3.100000    222.498157
# 75%       22.171875  1011.908743       0.205671       4.017461    224.229318
# max       25.000000  1013.054321       1.300000       5.125000    227.011935
#
#        cosphi_mean  cosphi_std  month_mean   hour_mean  dayofweek_mean  \
# count   143.000000  143.000000       143.0  143.000000           143.0
# mean      0.969541    0.001952         2.0   11.468531             4.0
# std       0.024300    0.001729         0.0    6.960456             0.0
# min       0.929293    0.000227         2.0    0.000000             4.0
# 25%       0.939837    0.000533         2.0    5.500000             4.0
# 50%       0.982728    0.001103         2.0   11.000000             4.0
# 75%       0.991566    0.003148         2.0   17.500000             4.0
# max       0.993933    0.008364         2.0   23.000000             4.0
#
#           p3_mean      p3_std  load_factor
# count  143.000000  143.000000   143.000000
# mean   251.684185    7.348058     0.951950
# std    173.714898    5.446918     0.024626
# min     70.200958    1.616689     0.809083
# 25%     79.407379    3.147965     0.943269
# 50%    168.524568    5.236843     0.955610
# 75%    438.555261   10.805837     0.967453
# max    527.387832   33.305255     0.987469

# %%
merged.describe()
# sobraram ?? pontos, de potenciais 98064
# Out:
#        temp_celsius     pression  precipitation  windspeed_mps  voltage_mean  \
# count    143.000000   143.000000     143.000000     143.000000    143.000000
# mean      21.297203  1010.524350       0.153000       2.957437    222.829559
# std        1.609649     1.644249       0.237205       1.249292      1.796251
# min       19.000000  1006.900000       0.000000       1.071111    220.005119
# 25%       20.000000  1009.711944       0.000000       1.841630    221.343998
# 50%       20.962963  1010.552517       0.074074       3.100000    222.498157
# 75%       22.171875  1011.908743       0.205671       4.017461    224.229318
# max       25.000000  1013.054321       1.300000       5.125000    227.011935
#
#        cosphi_mean  cosphi_std  month_mean   hour_mean  dayofweek_mean  \
# count   143.000000  143.000000       143.0  143.000000           143.0
# mean      0.969541    0.001952         2.0   11.468531             4.0
# std       0.024300    0.001729         0.0    6.960456             0.0
# min       0.929293    0.000227         2.0    0.000000             4.0
# 25%       0.939837    0.000533         2.0    5.500000             4.0
# 50%       0.982728    0.001103         2.0   11.000000             4.0
# 75%       0.991566    0.003148         2.0   17.500000             4.0
# max       0.993933    0.008364         2.0   23.000000             4.0
#
#           p3_mean      p3_std  load_factor
# count  143.000000  143.000000   143.000000
# mean   251.684185    7.348058     0.951950
# std    173.714898    5.446918     0.024626
# min     70.200958    1.616689     0.809083
# 25%     79.407379    3.147965     0.943269
# 50%    168.524568    5.236843     0.955610
# 75%    438.555261   10.805837     0.967453
# max    527.387832   33.305255     0.987469

# %%
merged.describe()
# Out:
#        temp_celsius     pression  precipitation  windspeed_mps  voltage_mean  \
# count    143.000000   143.000000     143.000000     143.000000    143.000000
# mean      21.297203  1010.524350       0.153000       2.957437    222.829559
# std        1.609649     1.644249       0.237205       1.249292      1.796251
# min       19.000000  1006.900000       0.000000       1.071111    220.005119
# 25%       20.000000  1009.711944       0.000000       1.841630    221.343998
# 50%       20.962963  1010.552517       0.074074       3.100000    222.498157
# 75%       22.171875  1011.908743       0.205671       4.017461    224.229318
# max       25.000000  1013.054321       1.300000       5.125000    227.011935
#
#        cosphi_mean  cosphi_std  month_mean   hour_mean  dayofweek_mean  \
# count   143.000000  143.000000       143.0  143.000000           143.0
# mean      0.969541    0.001952         2.0   11.468531             4.0
# std       0.024300    0.001729         0.0    6.960456             0.0
# min       0.929293    0.000227         2.0    0.000000             4.0
# 25%       0.939837    0.000533         2.0    5.500000             4.0
# 50%       0.982728    0.001103         2.0   11.000000             4.0
# 75%       0.991566    0.003148         2.0   17.500000             4.0
# max       0.993933    0.008364         2.0   23.000000             4.0
#
#           p3_mean      p3_std  load_factor
# count  143.000000  143.000000   143.000000
# mean   251.684185    7.348058     0.951950
# std    173.714898    5.446918     0.024626
# min     70.200958    1.616689     0.809083
# 25%     79.407379    3.147965     0.943269
# 50%    168.524568    5.236843     0.955610
# 75%    438.555261   10.805837     0.967453
# max    527.387832   33.305255     0.987469

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2018-02-01 00:00:00 to 2018-02-01 23:50:00
# Data columns (total 13 columns):
# temp_celsius      143 non-null float64
# pression          143 non-null float64
# precipitation     143 non-null float64
# windspeed_mps     143 non-null float64
# voltage_mean      143 non-null float64
# cosphi_mean       143 non-null float64
# cosphi_std        143 non-null float64
# month_mean        143 non-null float64
# hour_mean         143 non-null float64
# dayofweek_mean    143 non-null float64
# p3_mean           143 non-null float64
# p3_std            143 non-null float64
# load_factor       143 non-null float64
# dtypes: float64(13)
# memory usage: 15.6 KB

# %%
merged.iloc[0]['month_mean']=3
merged.iloc[0]['dayofweek_mean']=3
#TODO: remove this zero-std workarround

X = merged.drop('p3_mean', axis=1)
y = merged ['p3_mean']

X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X = (X - X_mean) / X_std

merged = pd.merge (X, y, how='inner', left_index=True, right_index=True)

# %% [markdown]
# # Output
# * 2 anos de medições em Brasilia, bloco C
# * Variables:
#   * temperature (float, interpolated. Unit: celsius)
#   * pressure (float, interpolated. Unit: hPa)
#   * precipitation (float, interpolated. Unit: mm)
#   * windspeed (float, interpolated. Unit: mps)
#   * voltage (float. Unit: Volts)
#   * cos_phi (float $\in [0,1]$. Unit: none)
#   * cos_phi_std (float. Unit: none)
#   * load_factor (float. Unit: none)
#   * month (Int $\in [1,12]$)
#   * day_of_week (Int $\in [0,6]$)
#   * hour (Int $\in [0,23]$)
#   * p3 (Float. Unit: KW)
#
# * Agregados a cada... 10min
# * to esperando uns 85MB (10min)

# %%
merged = merged.rename(columns={
    'temp_celsius': 'temperature', 
    'pression': 'pressure', 
    'precipitation': 'precipitation', 
    'windspeed_mps': 'windspeed', 
    'voltage_mean': 'voltage',
    'cosphi_mean': 'cos_phi', 
    'cosphi_std': 'cos_phi_std', 
    'load_factor': 'load_factor', 
    'month_mean': 'month', 
    'dayofweek_mean': 'day_of_week', 
    'hour_mean': 'hour', 
    'p3_std': 'p3_std',
    'p3_mean': 'p3'
})

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2018-02-01 00:00:00 to 2018-02-01 23:50:00
# Data columns (total 13 columns):
# temperature      143 non-null float64
# pressure         143 non-null float64
# precipitation    143 non-null float64
# windspeed        143 non-null float64
# voltage          143 non-null float64
# cos_phi          143 non-null float64
# cos_phi_std      143 non-null float64
# month            143 non-null float64
# hour             143 non-null float64
# day_of_week      143 non-null float64
# p3_std           143 non-null float64
# load_factor      143 non-null float64
# p3               143 non-null float64
# dtypes: float64(13)
# memory usage: 15.6 KB

# %%
merged.describe()
# Out:
#         temperature      pressure  precipitation     windspeed       voltage  \
# count  1.430000e+02  1.430000e+02   1.430000e+02  1.430000e+02  1.430000e+02
# mean  -1.937844e-15  3.066762e-13   1.801201e-16 -1.117987e-15  9.490466e-15
# std    1.003515e+00  1.003515e+00   1.003515e+00  1.003515e+00  1.003515e+00
# min   -1.432162e+00 -2.212007e+00  -6.472797e-01 -1.515223e+00 -1.577935e+00
# 25%   -8.087246e-01 -4.958262e-01  -6.472797e-01 -8.962907e-01 -8.299409e-01
# 50%   -2.083776e-01  1.719076e-02  -3.339039e-01  1.145159e-01 -1.851450e-01
# 75%    5.453033e-01  8.449200e-01   2.228276e-01  8.514820e-01  7.820065e-01
# max    2.308462e+00  1.544087e+00   4.852464e+00  1.741131e+00  2.336577e+00
#
#             cos_phi   cos_phi_std         month          hour   day_of_week  \
# count  1.430000e+02  1.430000e+02  1.430000e+02  1.430000e+02  1.430000e+02
# mean  -1.537853e-14 -5.962596e-16 -1.142831e-15 -4.968830e-17  1.142831e-15
# std    1.003515e+00  1.003515e+00  1.003515e+00  1.003515e+00  1.003515e+00
# min   -1.662106e+00 -1.001026e+00 -8.391814e-02 -1.653461e+00 -1.191638e+01
# 25%   -1.226656e+00 -8.236819e-01 -8.391814e-02 -8.605055e-01  8.391814e-02
# 50%    5.445846e-01 -4.924484e-01 -8.391814e-02 -6.754993e-02  8.391814e-02
# 75%    9.095645e-01  6.941876e-01 -8.391814e-02  8.695794e-01  8.391814e-02
# max    1.007286e+00  3.722333e+00  1.191638e+01  1.662535e+00  8.391814e-02
#
#              p3_std   load_factor          p3
# count  1.430000e+02  1.430000e+02  143.000000
# mean   2.732857e-16 -4.931564e-15  251.684185
# std    1.003515e+00  1.003515e+00  173.714898
# min   -1.055921e+00 -5.821798e+00   70.200958
# 25%   -7.738057e-01 -3.537342e-01   79.407379
# 50%   -3.889605e-01  1.491326e-01  168.524568
# 75%    6.370454e-01  6.317670e-01  438.555261
# max    4.782234e+00  1.447387e+00  527.387832

# %%
Axis = merged.plot(subplots=True, sharex=True, figsize=(12,8))
for k in range(0,merged.shape[1],1):
    Axis[k].legend(loc='upper left')
if FLAG_EXPORT: plt.savefig('graph_temporal.svg', format='svg')

# %%
merged.to_csv("../../datasets/brasilia_case_preprocessed.csv")
