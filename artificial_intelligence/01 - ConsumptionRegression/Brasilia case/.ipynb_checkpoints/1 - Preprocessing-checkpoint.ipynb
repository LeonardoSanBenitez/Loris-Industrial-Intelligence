# %% [markdown]
# # Conceptualization
# * This component takes two CSV files as input
# * Those CSV can be generated from a excel file, a SQL or non-SQL database, a power BI enviroment, and so forth

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10000000)

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

FLAG_EXPORT = True

out_path = 'assets/'

# %%
raw1 = pd.read_csv ("../../datasets/brasilia_case_climatic.csv", header=0)
raw1.head()
# Out:
#                 timestamp  temp_celsius  pression  precipitation  \
# 0  2018-01-31 00:00:00-02            21    1011.7            0.0
# 1  2018-01-31 01:00:00-02            21    1011.5            0.0
# 2  2018-01-31 02:00:00-02            20    1011.0            0.0
# 3  2018-01-31 03:00:00-02            20    1010.2            0.0
# 4  2018-01-31 04:00:00-02            20    1009.9            0.0
#
#    windspeed_mps
# 0            1.2
# 1            1.5
# 2            1.8
# 3            1.7
# 4            1.8

# %%
raw1.describe()
# Out:
#        temp_celsius      pression  precipitation  windspeed_mps
# count  16365.000000  16365.000000   16365.000000   16365.000000
# mean      21.709502   1015.286227       0.093981       2.228555
# std        3.870892      3.177252       0.504643       1.040920
# min       10.000000   1005.100000       0.000000       0.000000
# 25%       19.000000   1013.100000       0.000000       1.500000
# 50%       21.000000   1015.100000       0.000000       2.000000
# 75%       24.000000   1017.400000       0.000000       2.800000
# max       34.000000   1026.300000      18.000000       7.900000

# %%
raw1.plot.kde(subplots=True, sharex=False, figsize=(10,4), layout=(2,2))
if FLAG_EXPORT: plt.savefig(out_path+'graph_kde1.svg', format='svg')

# %%
raw1['timestamp'] = pd.to_datetime (raw1['timestamp'], utc=True)
raw1 = raw1.set_index(raw1.timestamp)
raw1 = raw1.drop ('timestamp', axis=1)

raw1 = raw1.set_index(raw1.index.tz_convert(None) + pd.offsets.Hour(-2)) # correct to brazilian timezone

# %%
filtered1 = raw1.resample('10min').interpolate(method='linear', limit_area='inside')

# %% [markdown]
# # Electrical database exploration
# * Convert index to timestamp
# * Resample by hour
# * Calculates load factor

# %%
raw2 = pd.read_csv ("../../datasets/brasilia_case_electric.csv", header=0)
raw2.describe()
# Out:
#                   p3             s3         cosphi        voltage  \
# count  857147.000000  857147.000000  857147.000000  857147.000000
# mean      183.425452     188.216562       0.953158     223.184563
# std       155.860108     155.022113       0.032707       2.766074
# min        48.737500      53.590995       0.830174     208.966000
# 25%        74.080833      80.127747       0.925084     221.431000
# 50%        89.919167      95.665319       0.946635     223.134667
# 75%       287.483155     289.455420       0.990457     224.994306
# max       713.428333     719.000686       0.999890     237.393444
#
#                month           hour      dayofweek
# count  987841.000000  987841.000000  987841.000000
# mean        6.672017      11.499988       3.000001
# std         3.268192       6.922196       2.000000
# min         1.000000       0.000000       0.000000
# 25%         4.000000       5.000000       1.000000
# 50%         7.000000      11.000000       3.000000
# 75%         9.000000      17.000000       5.000000
# max        12.000000      23.000000       6.000000

# %%
raw2[['p3', 's3', 'cosphi', 'voltage']].plot.kde(subplots=True, sharex=False, figsize=(10,4), layout=(2,2))
if FLAG_EXPORT: plt.savefig(out_path+'graph_kde2.svg', format='svg')

# %%
raw2['timestamp'] = pd.to_datetime (raw2['timestamp']) # already was in brazilian timezone
raw2 = raw2.set_index(raw2.timestamp)
raw2 = raw2.drop ('timestamp', axis=1)

# %%
# Resample
resampled2 = raw2.resample('10min').agg({
    'voltage': ['mean', 'count'],
    'cosphi': ['mean', 'std'],
    'month': ['mean'],
    'hour': ['mean'],
    'dayofweek': ['mean'],
    'p3': ['mean', 'max', 'std']
})

resampled2.columns = resampled2.columns.map('_'.join)
resampled2 = resampled2.dropna()
#resampled2.plot(subplots=True)

# %%
filtered2 = resampled2[(resampled2['voltage_count'] == 10)]
filtered2 = filtered2.drop('voltage_count', axis=1)

# %%
filtered2['load_factor'] = filtered2['p3_mean']/filtered2['p3_max']

# %%
filtered2 = filtered2.drop('p3_max', axis=1)

# %%
filtered2.head()
# Out:
#                      voltage_mean  cosphi_mean  cosphi_std  month_mean  \
# timestamp
# 2018-02-01 00:00:00    222.422553     0.931323    0.003132           2
# 2018-02-01 00:10:00    221.822300     0.938584    0.003327           2
# 2018-02-01 00:20:00    222.539326     0.933304    0.004393           2
# 2018-02-01 00:30:00    222.744070     0.934903    0.005175           2
# 2018-02-01 00:40:00    222.832179     0.936927    0.003765           2
#
#                      hour_mean  dayofweek_mean    p3_mean    p3_std  \
# timestamp
# 2018-02-01 00:00:00          0               4  76.384250  2.901398
# 2018-02-01 00:10:00          0               4  79.409299  4.679058
# 2018-02-01 00:20:00          0               4  74.200246  3.366907
# 2018-02-01 00:30:00          0               4  76.059915  2.742411
# 2018-02-01 00:40:00          0               4  77.216275  2.191767
#
#                      load_factor
# timestamp
# 2018-02-01 00:00:00     0.936588
# 2018-02-01 00:10:00     0.916590
# 2018-02-01 00:20:00     0.950006
# 2018-02-01 00:30:00     0.949632
# 2018-02-01 00:40:00     0.963748

# %% [markdown]
# # Data integration
# * if precipitation<0: precipitation=0

# %%
merged = pd.merge (filtered1, filtered2,how='inner', left_index=True, right_index=True).astype('float')

# %%
merged.loc[merged['precipitation']<0, 'precipitation']=0

# %%
merged = merged.rename(columns={
    'temp_celsius': 'temperature', 
    'pression': 'pressure', 
    'precipitation': 'precipitation', 
    'windspeed_mps': 'windspeed', 
    'voltage_mean': 'voltage',
    'cosphi_mean': 'cos_phi', 
    'cosphi_std': 'cos_phi_std', 
    'load_factor': 'load_factor', 
    'month_mean': 'month', 
    'dayofweek_mean': 'day_of_week', 
    'hour_mean': 'hour', 
    'p3_std': 'p3_std',
    'p3_mean': 'p3'
})

# %%
if FLAG_EXPORT: merged.describe().to_latex(out_path+'table_dataset_stats.tex')
# sobraram 84926 pontos, de potenciais 686*24*60/10=98784

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84926 entries, 2018-02-01 00:00:00 to 2019-12-13 23:00:00
# Data columns (total 13 columns):
# temperature      84926 non-null float64
# pressure         84926 non-null float64
# precipitation    84926 non-null float64
# windspeed        84926 non-null float64
# voltage          84926 non-null float64
# cos_phi          84926 non-null float64
# cos_phi_std      84926 non-null float64
# month            84926 non-null float64
# hour             84926 non-null float64
# day_of_week      84926 non-null float64
# p3               84926 non-null float64
# p3_std           84926 non-null float64
# load_factor      84926 non-null float64
# dtypes: float64(13)
# memory usage: 9.1 MB

# %%
merged['2019-03-01 00:00:00':'2019-05-01 00:00:00'].tail()
# Out:
#                      temperature  pressure  precipitation  windspeed  \
# timestamp
# 2019-04-30 23:20:00    -0.417746  0.196611      -0.184305  -0.666979
# 2019-04-30 23:30:00    -0.417746  0.223508      -0.184305  -0.634409
# 2019-04-30 23:40:00    -0.417746  0.250405      -0.184305  -0.601840
# 2019-04-30 23:50:00    -0.417746  0.277302      -0.184305  -0.569270
# 2019-05-01 00:00:00    -0.417746  0.304200      -0.184305  -0.536700
#
#                       voltage   cos_phi  cos_phi_std     month      hour  \
# timestamp
# 2019-04-30 23:20:00  0.618793 -1.112681     1.075464 -0.708098  1.655251
# 2019-04-30 23:30:00  0.514669 -0.815293    -0.000686 -0.708098  1.655251
# 2019-04-30 23:40:00  0.606425 -0.846621     0.858340 -0.708098  1.655251
# 2019-04-30 23:50:00  0.144237 -0.787641     1.011053 -0.708098  1.655251
# 2019-05-01 00:00:00  0.002639 -0.656387     0.392817 -0.386938 -1.665639
#
#                      day_of_week    p3_std  load_factor         p3
# timestamp
# 2019-04-30 23:20:00    -0.516081 -0.439208    -0.495163  76.899583
# 2019-04-30 23:30:00    -0.516081 -0.858090     0.712450  78.644250
# 2019-04-30 23:40:00    -0.516081 -0.637726    -0.086676  78.740500
# 2019-04-30 23:50:00    -0.516081 -0.547744     0.068180  74.651083
# 2019-05-01 00:00:00    -0.011584 -0.405587    -0.859286  76.130389

# %%
Axis = merged['2019-03-01 00:00:00':'2019-04-30 23:59:59'].plot(subplots=True, sharex=True, figsize=(15,13))
for k in range(0,merged.shape[1],1):
    Axis[k].legend(loc='upper left')
if FLAG_EXPORT: plt.savefig(out_path+'graph_temporal.svg', format='svg')

# %%
#merged.iloc[0]['month_mean']=3
#merged.iloc[0]['dayofweek_mean']=3
#TODO: remove this zero-std workarround

X = merged.drop('p3', axis=1)
y = merged ['p3']

X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X = (X - X_mean) / X_std

merged = pd.merge (X, y, how='inner', left_index=True, right_index=True)

# %% [markdown]
# # Output
# * 2 anos de medições em Brasilia, bloco C
# * Variables:
#   * temperature (float, interpolated. Unit: celsius)
#   * pressure (float, interpolated. Unit: hPa)
#   * precipitation (float, interpolated. Unit: mm)
#   * windspeed (float, interpolated. Unit: mps)
#   * voltage (float. Unit: Volts)
#   * cos_phi (float $\in [0,1]$. Unit: none)
#   * cos_phi_std (float. Unit: none)
#   * load_factor (float. Unit: none)
#   * month (Int $\in [1,12]$)
#   * day_of_week (Int $\in [0,6]$)
#   * hour (Int $\in [0,23]$)
#   * p3 (Float. Unit: KW)
#
# * Agregados a cada... 10min
# * to esperando uns 85MB (10min)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84926 entries, 2018-02-01 00:00:00 to 2019-12-13 23:00:00
# Data columns (total 13 columns):
# temperature      84926 non-null float64
# pressure         84926 non-null float64
# precipitation    84926 non-null float64
# windspeed        84926 non-null float64
# voltage          84926 non-null float64
# cos_phi          84926 non-null float64
# cos_phi_std      84926 non-null float64
# month            84926 non-null float64
# hour             84926 non-null float64
# day_of_week      84926 non-null float64
# p3_std           84926 non-null float64
# load_factor      84926 non-null float64
# p3               84926 non-null float64
# dtypes: float64(13)
# memory usage: 11.6 MB

# %%
merged.describe()
# Out:
#         temperature      pressure  precipitation     windspeed       voltage  \
# count  8.492600e+04  8.492600e+04   8.492600e+04  8.492600e+04  8.492600e+04
# mean  -3.009302e-15  1.097142e-12  -1.127150e-15  1.307601e-14  9.715281e-13
# std    1.000006e+00  1.000006e+00   1.000006e+00  1.000006e+00  1.000006e+00
# min   -3.017813e+00 -3.181672e+00  -1.843052e-01 -2.197754e+00 -4.787499e+00
# 25%   -6.777531e-01 -6.856158e-01  -1.843052e-01 -6.832638e-01 -6.350920e-01
# 50%   -1.577396e-01 -4.546344e-02  -1.843052e-01 -1.947186e-01 -1.957806e-02
# 75%    7.089494e-01  6.700009e-01  -1.843052e-01  5.380993e-01  6.571054e-01
# max    3.222348e+00  3.467305e+00   4.199298e+01  5.521260e+00  4.976406e+00
#
#             cos_phi   cos_phi_std         month          hour   day_of_week  \
# count  8.492600e+04  8.492600e+04  8.492600e+04  8.492600e+04  8.492600e+04
# mean  -6.012313e-14 -4.310478e-16 -9.638335e-17  1.157102e-16  2.108386e-17
# std    1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00
# min   -3.062172e+00 -1.209125e+00 -1.671578e+00 -1.665639e+00 -1.525074e+00
# 25%   -8.694246e-01 -9.255688e-01 -7.080978e-01 -7.993197e-01 -1.020577e+00
# 50%   -2.125279e-01 -1.571318e-01 -6.577792e-02  6.699931e-02 -1.158383e-02
# 75%    1.146815e+00  6.277824e-01  8.977019e-01  9.333183e-01  9.974096e-01
# max    1.375603e+00  1.075037e+01  1.861182e+00  1.655251e+00  1.501906e+00
#
#              p3_std   load_factor            p3
# count  8.492600e+04  8.492600e+04  84926.000000
# mean   7.107603e-15  1.497101e-13    183.422097
# std    1.000006e+00  1.000006e+00    155.619762
# min   -1.117884e+00 -1.219653e+01     52.673333
# 25%   -6.122363e-01 -5.151269e-01     74.133104
# 50%   -3.188324e-01  1.735372e-01     89.419042
# 75%    3.178812e-01  7.097525e-01    287.467708
# max    1.676386e+01  1.847771e+00    692.232000

# %%
Axis = merged.plot(subplots=True, sharex=True, figsize=(12,8))
for k in range(0,merged.shape[1],1):
    Axis[k].legend(loc='upper left')
if FLAG_EXPORT: plt.savefig(out_path+'graph_temporal_scaled.svg', format='svg')

# %%
merged.to_csv("../../datasets/brasilia_case_preprocessed.csv")
